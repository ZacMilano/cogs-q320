# %% [markdown]
# # Assignment 0
# ## Zac Monroe
# ## Q320

# %%
# I am unnecessarily strict when it comes to using double quotes instead of single quotes
print("Hello world!")
# Out:
# Hello world!

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)
xs = 6 * np.random.rand(200) - 3
ys = np.sin(xs)

plt.title("Proof of installation")
plt.scatter(xs, ys)
